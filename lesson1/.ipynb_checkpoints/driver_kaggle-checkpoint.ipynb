# %% [markdown]
# # Driver Kaggle

# %% [markdown]
# I start by downloading and and unziping the competition data from Kaggle and ensure my directory structure looks like this
# ```
# utils/
#     vgg16.py
#     utils.py
# lesson1/
#     driver_kaggle.ipynb
#     data/
#         driver/
#             train/
#                 ...
#             test/
#                 ...
# ```
# ```$ sudo apt-get install python-pip python-dev build-essential
# $ sudo pip install --upgrade pip
# $ sudo pip install --upgrade virtualenv
# $ sudo apt-get install kaggle-cli
# $ kg download -u 'username' -p 'pwd' -c 'state-farm-distracted-driver-detection'
# $ sudo apt-get install ffmpeg #if need to get out of MemoryError```
#
# You can download the data files from the competition page [here](https://www.kaggle.com/c/state-farm-distracted-driver-detection/data) or you can download them from the command line using the [Kaggle CLI](https://github.com/floydwch/kaggle-cli).
#
# Then I launch your notebook inside the lesson1 directory
# ```
# cd lesson1
# jupyter notebook
# ```

# %%
# %cd
# %cd nbs/lesson1
# %pwd
# Out:
# /home/ubuntu
# /home/ubuntu/nbs/lesson1
# u'/home/ubuntu/nbs/lesson1'

# %%
# %cd data/driver/train
# Out:
# /home/ubuntu/nbs/lesson1/data/driver/train

# %%
# %mkdir ../valid
# %mkdir ../results
# Out:
# mkdir: cannot create directory ‘../valid’: File exists
# mkdir: cannot create directory ‘../results’: File exists

# %% [markdown]
# ## Action Plan
# 1. Create Validation and Sample sets
# 2. Rearrange image files into their respective directories
# 3. Finetune and Train model
# 4. Generate predictions
# 5. Validate predictions
# 6. Submit predictions to Kaggle

# %%
# %matplotlib inline
path = 'data/driver/'
result_path = 'data/driver/results/'
# %cd
# %cd nbs
# Out:
# /home/ubuntu
# /home/ubuntu/nbs

# %%
import os, json
from glob import glob
import numpy as np

from utils import *
# %cd
# %cd nbs/lesson1/data/driver/train
# Out:
# /home/ubuntu
# /home/ubuntu/nbs/lesson1/data/driver/train

# %% [markdown]
# #### <font color=blue> Create validation set and sample</font>

# %%
for d in glob('c?'):
    os.mkdir('../valid/'+d)
    g = glob(d+'/*.jpg')
    shuf = np.random.permutation(g)
    for i in range(200):
        os.rename(shuf[i], '../valid/' + shuf[i])

# %%
# %mkdir ../sample

# %%
# %cd
# %cd nbs
# Out:
# /home/ubuntu
# /home/ubuntu/nbs

# %% [markdown]
# #### <font color=blue> Finetuning and train</font>

# %%
from vgg16 import Vgg16

# %%
vgg = Vgg16()

# %%
batch_size=64
nb_of_epochs=1

# %%
# %cd 
# %cd nbs/lesson1/
# Out:
# /home/ubuntu
# /home/ubuntu/nbs/lesson1

# %%
batches = vgg.get_batches('/home/ubuntu/nbs/lesson1/data/driver/train/', batch_size=batch_size)
val_batches = vgg.get_batches('/home/ubuntu/nbs/lesson1/data/driver/valid/', batch_size=batch_size)
vgg.finetune(batches)
vgg.model.optimizer.lr = 0.01
# Out:
# Found 16424 images belonging to 10 classes.
# Found 2000 images belonging to 10 classes.

# %%
#vgg.finetune(batches)
#vgg.fit(batches, val_batches, nb_epoch=0.01)
# Out:
# Epoch 1/0
# Exception in thread Thread-9:
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda2/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/ubuntu/anaconda2/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/keras/engine/training.py", line 425, in data_generator_task
#     generator_output = next(generator)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/keras/preprocessing/image.py", line 600, in next
#     img = load_img(os.path.join(self.directory, fname), grayscale=grayscale, target_size=self.target_size)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/keras/preprocessing/image.py", line 173, in load_img
#     img = Image.open(path)
#   File "/home/ubuntu/anaconda2/lib/python2.7/site-packages/PIL/Image.py", line 2280, in open
#     fp = builtins.open(filename, "rb")
# IOError: [Errno 2] No such file or directory: 'data/driver/train/c5/img_102055.jpg'
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-93-f002677761cd> in <module>()
#       1 vgg.finetune(batches)
# ----> 2 vgg.fit(batches, val_batches, nb_epoch=0.01)
#
# vgg16.pyc in fit(self, batches, val_batches, nb_epoch)
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/keras/models.pyc in fit_generator(self, generator, samples_per_epoch, nb_epoch, verbose, callbacks, validation_data, nb_val_samples, class_weight, max_q_size, nb_worker, pickle_safe, **kwargs)
#     872                                         max_q_size=max_q_size,
#     873                                         nb_worker=nb_worker,
# --> 874                                         pickle_safe=pickle_safe)
#     875
#     876     def evaluate_generator(self, generator, val_samples, max_q_size=10, nb_worker=1, pickle_safe=False, **kwargs):
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/keras/engine/training.pyc in fit_generator(self, generator, samples_per_epoch, nb_epoch, verbose, callbacks, validation_data, nb_val_samples, class_weight, max_q_size, nb_worker, pickle_safe)
#    1415                     raise Exception('output of generator should be a tuple '
#    1416                                     '(x, y, sample_weight) '
# -> 1417                                     'or (x, y). Found: ' + str(generator_output))
#    1418                 if len(generator_output) == 2:
#    1419                     x, y = generator_output
#
# Exception: output of generator should be a tuple (x, y, sample_weight) or (x, y). Found: None

# %%
#vgg.finetune(batches)
#vgg.model.optimizer.lr = 0.01

# %%
latest_weights_filename = None
for epoch in range(nb_of_epochs):
    print "Running epoch: %d" % epoch
    vgg.fit(batches, val_batches, nb_epoch=0.01)
    latest_weights_filename = 'ft%d.h5' % epoch
    vgg.model.save_weights(result_path+latest_weights_filename)
print "Completed %s fit operations" % nb_of_epochs
# Out:
# Running epoch: 0
# Epoch 1/0
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-113-bc04c3ae9631> in <module>()
#       2 for epoch in range(nb_of_epochs):
#       3     print "Running epoch: %d" % epoch
# ----> 4     vgg.fit(batches, val_batches, nb_epoch=0.1)
#       5     latest_weights_filename = 'ft%d.h5' % epoch
#       6     vgg.model.save_weights(result_path+latest_weights_filename)
#
# vgg16.pyc in fit(self, batches, val_batches, nb_epoch)
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/keras/models.pyc in fit_generator(self, generator, samples_per_epoch, nb_epoch, verbose, callbacks, validation_data, nb_val_samples, class_weight, max_q_size, nb_worker, pickle_safe, **kwargs)
#     872                                         max_q_size=max_q_size,
#     873                                         nb_worker=nb_worker,
# --> 874                                         pickle_safe=pickle_safe)
#     875
#     876     def evaluate_generator(self, generator, val_samples, max_q_size=10, nb_worker=1, pickle_safe=False, **kwargs):
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/keras/engine/training.pyc in fit_generator(self, generator, samples_per_epoch, nb_epoch, verbose, callbacks, validation_data, nb_val_samples, class_weight, max_q_size, nb_worker, pickle_safe)
#    1425                     raise Exception('output of generator should be a tuple '
#    1426                                     '(x, y, sample_weight) '
# -> 1427                                     'or (x, y). Found: ' + str(generator_output))
#    1428                 # build batch logs
#    1429                 batch_logs = {}
#
# Exception: output of generator should be a tuple (x, y, sample_weight) or (x, y). Found: [[[[  39.   39.   39. ...,  215.  179.   11.]
#    [  39.   39.   39. ...,  197.  186.    6.]
#    [  38.   38.   38. ...,  182.  174.    5.]
#    ...,
#    [   6.    6.    6. ...,   18.   13.    9.]
#    [   6.    6.    6. ...,   24.   11.   13.]
#    [   6.    6.    6. ...,   39.   11.   15.]]
#
#   [[  46.   46.   46. ...,  255.  207.   14.]
#    [  46.   46.   46. ...,  248.  222.   16.]
#    [  45.   45.   45. ...,  248.  220.   21.]
#    ...,
#    [   7.    7.    7. ...,   18.   12.   11.]
#    [   7.    7.    7. ...,   24.   10.   13.]
#    [   7.    7.    7. ...,   41.   10.   15.]]
#
#   [[  30.   30.   30. ...,  255.  210.   19.]
#    [  30.   30.   30. ...,  249.  222.   17.]
#    [  29.   29.   29. ...,  246.  217.   18.]
#    ...,
#    [   2.    2.    2. ...,   18.   10.    8.]
#    [   2.    2.    2. ...,   24.    8.   11.]
#    [   2.    2.    2. ...,   40.    8.   13.]]]
#
#
#  [[[  62.   62.   64. ...,  159.  175.   25.]
#    [  61.   61.   66. ...,  137.  181.   35.]
#    [  69.   69.   76. ...,  139.  186.  114.]
#    ...,
#    [   8.    6.    5. ...,   19.   22.   10.]
#    [   8.    6.    5. ...,   16.   16.   18.]
#    [   8.    6.    5. ...,   13.   12.   16.]]
#
#   [[  77.   77.   79. ...,  228.  224.   47.]
#    [  75.   75.   80. ...,  208.  232.   58.]
#    [  79.   79.   86. ...,  216.  241.  141.]
#    ...,
#    [   9.    7.    6. ...,   18.   21.    9.]
#    [   9.    7.    6. ...,   15.   15.   17.]
#    [   9.    7.    6. ...,   12.   11.   15.]]
#
#   [[  56.   56.   58. ...,  244.  241.   60.]
#    [  52.   52.   57. ...,  226.  251.   74.]
#    [  54.   54.   61. ...,  234.  255.  160.]
#    ...,
#    [   6.    6.    6. ...,   13.   23.   30.]
#    [   5.    6.    6. ...,   17.   22.   27.]
#    [   4.    5.    7. ...,   24.   22.   23.]]
#
#   [[  51.   51.   54. ...,  255.  255.   23.]
#    [  53.   53.   55. ...,  254.  255.   54.]
#    [  55.   56.   58. ...,  255.  245.  150.]
#    ...,
#    [   7.    7.    7. ...,   13.   24.   33.]
#    [   6.    7.    7. ...,   17.   26.   33.]
#    [   5.    6.    8. ...,   25.   27.   32.]]
#
#   [[  46.   46.   48. ...,  255.  255.   27.]
#    [  46.   46.   47. ...,  255.  255.   57.]
#    [  47.   48.   49. ...,  255.  246.  152.]
#    ...,
#    [   2.    2.    2. ...,   15.   26.   38.]
#    [   1.    2.    2. ...,   17.   25.   33.]
#    [   0.    1.    3. ...,   20.   21.   29.]]]]

# %%
vgg.classes[:10]
# Out:
# ['c0', 'c1', 'c2', 'c3', 'c4', 'c5', 'c6', 'c7', 'c8', 'c9']

# %% [markdown]
# #### <font color=blue> Generate Prodictions</font>

# %%
#vgg.model.save_weights(result_path+'driver_kaggle1.h5')

# %%
# %cd lesson1/
# Out:
# /home/ubuntu/nbs/lesson1

# %%
vgg.model.load_weights(result_path+latest_weights_filename)

# %%
test_path = '/home/ubuntu/nbs/lesson1/data/driver/train'
batches, preds = vgg.test(test_path, batch_size = batch_size)
# Out:
# Found 16424 images belonging to 10 classes.

# %%
print preds[:5]
filenames = batches.filenames
print filenames[:5]
# Out:
# [[  0.0000e+00   0.0000e+00   0.0000e+00   1.6444e-12   1.0000e+00   6.5228e-15   1.4259e-40
#     1.0384e-42   0.0000e+00   1.2778e-12]
#  [  0.0000e+00   0.0000e+00   0.0000e+00   1.8087e-06   1.7642e-01   1.5908e-08   3.1269e-36
#     1.5397e-36   1.4013e-45   8.2357e-01]
#  [  0.0000e+00   0.0000e+00   1.0650e-43   1.5451e-11   3.6749e-02   9.1681e-01   1.1644e-29
#     5.8589e-40   5.6052e-45   4.6437e-02]
#  [  3.7860e-39   0.0000e+00   7.0065e-45   4.0286e-17   2.7134e-01   1.9592e-16   2.9191e-28
#     9.7124e-31   1.3051e-36   7.2866e-01]
#  [  1.6705e-41   0.0000e+00   6.3899e-43   7.8160e-11   6.4631e-09   1.0000e+00   7.6261e-31
#     1.1252e-26   6.7364e-38   6.0195e-07]]
# ['c0/img_95728.jpg', 'c0/img_74437.jpg', 'c0/img_58721.jpg', 'c0/img_21699.jpg', 'c0/img_2813.jpg']

# %%
test_path = '/home/ubuntu/nbs/lesson1/data/driver/train/'
from PIL import Image
Image.open(test_path + filenames[2])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480 at 0x7F97356D73D0>

# %%
save_array(result_path + 'test_preds.dat', preds)
save_array(result_path + 'filenames.dat', filenames)

# %% [markdown]
# #### <font color=blue> Validate Prodictions</font>

# %%
# %cd
# %cd nbs/lesson1
vgg.model.load_weights(result_path+'driver_kaggle1.h5')
# Out:
# /home/ubuntu
# /home/ubuntu/nbs/lesson1

# %%
valid_path = '/home/ubuntu/nbs/lesson1/data/driver/valid/'
val_batches, probs = vgg.test(valid_path, batch_size=batch_size)
# Out:
# Found 2000 images belonging to 10 classes.

# %%
filenames = val_batches.filenames
expected_labels = val_batches.classes #0 or 1
our_predictions = probs[:,0]
our_labels = np.round(1-our_predictions)

# %%
from keras.preprocessing import image
#Helper function to plot images by index in the validation set 
#Plots is a helper function in utils.py
def plots_idx(idx, titles=None):
    plots([image.load_img(valid_path + filenames[i]) for i in idx], titles=titles)
    
#Number of images to view for each visualization task
n_view = 4

# %% [markdown]
# #### <font color=green> Correct prediction </font>

# %%
correct = np.where(our_labels==expected_labels)[0]
print "Found %d correct labels" % len(correct)
idx = permutation(correct)[:n_view]
plots_idx(idx, our_predictions[idx])
# Out:
# Found 200 correct labels

# %% [markdown]
# #### <font color=red> Incorrect predictions </font>

# %%
incorrect = np.where(our_labels!=expected_labels)[0]
print "Found %d incorrect labels" % len(incorrect)
idx = permutation(incorrect)[:n_view]
plots_idx(idx, our_predictions[idx])
# Out:
# Found 1800 incorrect labels

# %%
vgg.classes[:10]
# Out:
# ['c0', 'c1', 'c2', 'c3', 'c4', 'c5', 'c6', 'c7', 'c8', 'c9']
